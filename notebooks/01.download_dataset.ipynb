# %%
import numpy as np
import pandas as pd
import matplotlib as pyplot

# %%
import json
with open("../artifacts/kaggle.json", 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'bapudara', 'key': 'd1620fd2e6b9e8ac9371281dfaf16ecd'}

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (2.1.0)
# Requirement already satisfied: bleach in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: jupytext in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (0.1.22)
# Requirement already satisfied: packaging in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (26.2)
# Requirement already satisfied: protobuf in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (7.34.1)
# Requirement already satisfied: python-dateutil in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (2.33.1)
# Requirement already satisfied: tqdm in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jupytext->kaggle) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jupytext->kaggle) (0.5.0)
# Requirement already satisfied: nbformat in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from nbformat->jupytext->kaggle) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.15.0)
# Requirement already satisfied: six>=1.5 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from requests->kaggle) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from requests->kaggle) (2026.4.22)
# Requirement already satisfied: colorama in C:\Users\pasan\OneDrive\Desktop\Project\ML\Sentiment-Analysis\env\Lib\site-packages (from tqdm->kaggle) (0.4.6)
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files("rehanliaqat17/imbd-dataset", path="../artifacts/")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rehanliaqat17/imbd-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/imbd-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
